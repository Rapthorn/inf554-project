# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df1 = pd.read_csv("gdrive/MyDrive/train_data.csv")
df2 = pd.read_csv("gdrive/MyDrive/evaluation_data.csv")
df = df1.append(df2, ignore_index = True)

# %%
df2
# Out:
#             id      timestamp  retweet_count  ...  positive  negative  text_size
# 0       665776  1588644489777            NaN  ...         0         0          6
# 1       665777  1588463988413            NaN  ...         0         0         20
# 2       665778  1588563932106            NaN  ...         0         0          5
# 3       665779  1588639210045            NaN  ...         1         0         32
# 4       665780  1588692867357            NaN  ...         1         1         53
# ...        ...            ...            ...  ...       ...       ...        ...
# 285329  951105  1588673869339            NaN  ...         0         0         44
# 285330  951106  1588296137844            NaN  ...         0         0         32
# 285331  951107  1588550324249            NaN  ...         0         0         46
# 285332  951108  1588656171612            NaN  ...         0         0          5
# 285333  951109  1588577717251            NaN  ...         0         0         22
#
# ...

# %%
df1 = pd.read_csv("gdrive/MyDrive/train.csv")
df2 = pd.read_csv("gdrive/MyDrive/evaluation.csv")
df_text = df1.append(df2, ignore_index = True)

# %%
df2
# Out:
#             id  ...                                               text
# 0       665776  ...  Coronavirus, no spring break, Chris Brown fan ...
# 1       665777  ...                                This fits the data.
# 2       665778  ...  Y’all talk about the Coronavirus like y’all be...
# 3       665779  ...  As this coronavirus and covid-19 go on, the fo...
# 4       665780  ...  Big Brother is not very good at watching you. ...
# ...        ...  ...                                                ...
# 285329  951105  ...  #IndianArmy fights COVID-19\n\n#HarKaamDeshKeN...
# 285330  951106  ...  (04/22/2020) “CUT-THE-RONA” \n\nWe would like ...
# 285331  951107  ...                                It's just starting.
# 285332  951108  ...  It is in no way a surprise that one of the fou...
# 285333  951109  ...            Very impressive https://t.co/xVAdPYh8IT
#
# [285334 rows x 10 columns]

# %%
df["text"] = df_text["text"]

# %%
df.nlargest(100, ["retweet_count"])
# Out:
#             id  ...                                               text
# 546442  546442  ...                Never Not 💜 https://t.co/Ag9oUTJvrN
# 565532  565532  ...  To all the little girls watching...never doubt...
# 225845  225845  ...                          ☺ https://t.co/9vNeJtA1vW
# 117825  117825  ...  Easily one of the best social distancing ads I...
# 622524  622524  ...  I can’t believe I have to say this, but please...
# ...        ...  ...                                                ...
# 448498  448498  ...  This is exactly how females are lmfaoooo https...
# 34401    34401  ...  We can now read the Imperial College report on...
# 636765  636765  ...  how tf am I an essential worker https://t.co/3...
# 651667  651667  ...  Very American to decide we are bored with COVI...
# 484978  484978  ...  If my husband cut like this without trying to ...
#
# [100 rows x 38 columns]

# %%
df[((df["user_statuses_count"] >= 12000) & (df["user_statuses_count"] <= 13000) &
    (df["user_friends_count"] >= 125) & (df["user_friends_count"] <= 145)
    & (df["user_followers_count"] >= 2000000))]
# Out:
#             id  ...                                               text
# 7357      7357  ...  염색 했을 때 촬칵 !! \n우리 아미 머해요옹??\n\n #BOTD #BTS_OF...
# 143257  143257  ...  가족들과 소중한 시간들이 되길 바랄게요😊\n#JIMIN https://t.co/PV...
# 225845  225845  ...                          ☺ https://t.co/9vNeJtA1vW
# 546442  546442  ...                Never Not 💜 https://t.co/Ag9oUTJvrN
# 877921  877920  ...  어버이날 카네이션은 역시 어린이날에 만들어야! https://t.co/rbWKmL3e9H
#
# [5 rows x 38 columns]

# %%
df.loc[:, "user"] = '0'

# %%
df.loc[((df["user_statuses_count"] >= 12000) & (df["user_statuses_count"] <= 13000) &
    (df["user_friends_count"] >= 125) & (df["user_friends_count"] <= 145)
    & (df["user_followers_count"] >= 2000000)), "user"] = 'BTS'

# %%
df.nlargest(15, ["retweet_count"]).loc[df.nlargest(15, ["retweet_count"])["user"] == '0']
# Out:
#             id  ...  user
# 565532  565532  ...     0
# 117825  117825  ...     0
# 622524  622524  ...     0
# 384422  384422  ...     0
# 556993  556993  ...     0
# 211555  211555  ...     0
# 275029  275029  ...     0
# 360433  360433  ...     0
# 67926    67926  ...     0
# 416321  416321  ...     0
# 419323  419323  ...     0
#
# [11 rows x 39 columns]

# %%
df[((df["user_statuses_count"] >= 10000) & (df["user_statuses_count"] <= 20000) &
    (df["user_friends_count"] >= 600) & (df["user_friends_count"] <= 1000)
    & (df["user_followers_count"] >= 27000000) )]
# Out:
#             id  ...  user
# 30575    30575  ...     0
# 106771  106771  ...     0
# 168972  168972  ...     0
# 214166  214166  ...     0
# 231204  231204  ...     0
# 252916  252916  ...     0
# 271654  271654  ...     0
# 315337  315337  ...     0
# 320928  320928  ...     0
# 333494  333494  ...     0
# 436197  436197  ...     0
# 446713  446713  ...     0
# 531115  531115  ...     0
# 549662  549662  ...     0
# 565532  565532  ...     0
# 565655  565655  ...     0
# 583463  583463  ...     0
# 584994  584994  ...     0
# 591761  591761  ...     0
# 663396  663396  ...     0
# 692694  692693  ...     0
# 700538  700537  ...     0
# 714188  714187  ...     0
# 833629  833628  ...     0
# 860494  860493  ...     0
# 922184  922183  ...     0
# 923675  923674  ...     0
#
# [27 rows x 39 columns]

# %%
df.loc[((df["user_statuses_count"] >= 10000) & (df["user_statuses_count"] <= 20000) &
    (df["user_friends_count"] >= 600) & (df["user_friends_count"] <= 1000)
    & (df["user_followers_count"] >= 27000000) ), "user"] = 'Hilary'

# %%
#pd.set_option("display.max_rows", None, "display.max_columns", None)
df.nlargest(15, ["retweet_count"]).loc[df.nlargest(15, ["retweet_count"])["user"] == '0']
# Out:
#             id  ...  user
# 117825  117825  ...     0
# 622524  622524  ...     0
# 384422  384422  ...     0
# 556993  556993  ...     0
# 211555  211555  ...     0
# 275029  275029  ...     0
# 360433  360433  ...     0
# 67926    67926  ...     0
# 416321  416321  ...     0
# 419323  419323  ...     0
#
# [10 rows x 39 columns]

# %%
df.loc[((df["user_statuses_count"] >= 1800) & (df["user_statuses_count"] <= 2100) &
    (df["user_friends_count"] >= 1400) & (df["user_friends_count"] <= 1550)
    & (df["user_followers_count"] >= 14000) )]
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 87524    87524  1588293605676           33.0              0
# 117825  117825  1588305672852       415787.0              0
# 230133  230133  1588579766499           39.0              0
# 239968  239968  1588315589397            2.0              0
# 310977  310977  1588353693708            7.0              0
# 351119  351119  1588501959971           17.0              0
# 364548  364548  1588315778568            5.0              0
# 500793  500793  1588673788124            3.0              0
# 562572  562572  1588315724447            5.0              0
# 562675  562675  1588315730127            3.0              0
# 574135  574135  1588545476085            0.0              1
# 614133  614133  1588315734478            2.0              0
# 629474  629474  1588679582956            4.0              0
# 631762  631762  1588608265385           45.0              0
# 693217  693216  1588633594813            NaN              0
# ...

# %%
df.loc[((df["user_statuses_count"] >= 1800) & (df["user_statuses_count"] <= 2100) & (df["user_friends_count"] ==1530)
    & (df["user_followers_count"] >= 14000) ), "user"] = 'Unique_user_1'

# %%
df.nlargest(100, ["retweet_count"]).loc[df.nlargest(100, ["retweet_count"])["user"] == '0']
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 622524  622524  1588611150023       334427.0              1
# 384422  384422  1588647768395       333211.0              0
# 556993  556993  1588544598803       252369.0              0
# 211555  211555  1588653470385       241820.0              1
# 275029  275029  1588676325397       235681.0              0
# 360433  360433  1588670638696       223983.0              1
# 67926    67926  1588672910115       209370.0              0
# 416321  416321  1588653801086       208844.0              0
# 419323  419323  1588711235137       208130.0              0
# 288191  288191  1588678495826       207384.0              0
# 618560  618560  1588659206678       204522.0              0
# 153971  153971  1588655712228       194810.0              1
# 197725  197725  1588679567664       187101.0              0
# 61201    61201  1588690552467       186897.0              0
# 408817  408817  1588663290885       185406.0              0
# ...

# %%
df.loc[((df["user_statuses_count"] >= 3000) & (df["user_statuses_count"] <= 8000) &
    (df["user_friends_count"] == 26)
    & (df["user_followers_count"] >= 5000000) & (df["user_followers_count"] <= 6000000) )]
# Out:
#             id  ...   user
# 2094      2094  ...  Biden
# 12819    12819  ...  Biden
# 20682    20682  ...  Biden
# 36605    36605  ...  Biden
# 47156    47156  ...  Biden
# ...        ...  ...    ...
# 913027  913026  ...  Biden
# 917775  917774  ...  Biden
# 923502  923501  ...  Biden
# 934645  934644  ...  Biden
# 950984  950983  ...  Biden
#
# [83 rows x 39 columns]

# %%
df.loc[((df["user_statuses_count"] >= 3000) & (df["user_statuses_count"] <= 8000) &
    (df["user_friends_count"] == 26)
    & (df["user_followers_count"] >= 5000000) & (df["user_followers_count"] <= 6000000) ), "user"] = 'Biden'

# %%
df.nlargest(30, ["retweet_count"]).loc[df.nlargest(30, ["retweet_count"])["user"] == '0']
# Out:
#             id  ...  user
# 117825  117825  ...     0
# 384422  384422  ...     0
# 556993  556993  ...     0
# 211555  211555  ...     0
# 275029  275029  ...     0
# 360433  360433  ...     0
# 67926    67926  ...     0
# 416321  416321  ...     0
# 419323  419323  ...     0
# 288191  288191  ...     0
# 618560  618560  ...     0
# 153971  153971  ...     0
# 197725  197725  ...     0
# 61201    61201  ...     0
# 408817  408817  ...     0
# 470317  470317  ...     0
# 535135  535135  ...     0
# 469058  469058  ...     0
# 210249  210249  ...     0
# 277334  277334  ...     0
# 224651  224651  ...     0
# 471393  471393  ...     0
# 340499  340499  ...     0
# 327965  327965  ...     0
#
# [24 rows x 39 columns]

# %%
df.loc[((df["user_statuses_count"] >= 150) & (df["user_statuses_count"] <= 170) &
    (df["user_friends_count"] >= 10) & (df["user_friends_count"] <= 15)
    & (df["user_followers_count"] >= 20000) & (df["user_followers_count"] <= 30000), "user" )] = "user_4th_pop_tweet"

# %%
df.nlargest(100, ["retweet_count"]).loc[df.nlargest(100, ["retweet_count"])["user"] == '0']
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 556993  556993  1588544598803       252369.0              0
# 211555  211555  1588653470385       241820.0              1
# 275029  275029  1588676325397       235681.0              0
# 360433  360433  1588670638696       223983.0              1
# 67926    67926  1588672910115       209370.0              0
# 416321  416321  1588653801086       208844.0              0
# 419323  419323  1588711235137       208130.0              0
# 288191  288191  1588678495826       207384.0              0
# 618560  618560  1588659206678       204522.0              0
# 153971  153971  1588655712228       194810.0              1
# 197725  197725  1588679567664       187101.0              0
# 61201    61201  1588690552467       186897.0              0
# 408817  408817  1588663290885       185406.0              0
# 470317  470317  1588700599996       178111.0              0
# 535135  535135  1588647965163       168249.0              1
# ...

# %%
df.loc[((df["user_statuses_count"] >= 15000) & (df["user_statuses_count"] <= 16000) &
    (df["user_friends_count"] >= 60000) & (df["user_friends_count"] <= 700000)
    & (df["user_followers_count"] >= 2000000))]
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 36710    36710  1588691847949        39569.0              1
# 40881    40881  1588702286963         6461.0              1
# 81059    81059  1588702322952        93528.0              1
# 223370  223370  1588641154414        10364.0              1
# 241246  241246  1588702306684        37942.0              1
# 267046  267046  1588637284954        51858.0              1
# 308445  308445  1588709550016        37549.0              1
# 324571  324571  1588696530079        10923.0              1
# 417192  417192  1588701971468       130964.0              1
# 469058  469058  1588630157117       166665.0              1
# 485631  485631  1588702172282         9971.0              1
# 529350  529350  1588703408686        42851.0              1
# 562049  562049  1588683453155        42531.0              1
# 582674  582674  1588565641877         5721.0              1
# 602831  602831  1588629732147        26530.0              1
# ...

# %%
df.loc[((df["user_statuses_count"] >= 15000) & (df["user_statuses_count"] <= 16000) &
    (df["user_friends_count"] >= 60000) & (df["user_friends_count"] <= 700000)
    & (df["user_followers_count"] >= 2000000)), "user"] = "Obama"

# %%
df.nlargest(100, ["retweet_count"]).loc[df.nlargest(100, ["retweet_count"])["user"] == '0']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-01eb731c0843> in <module>()
# ----> 1 df.nlargest(100, ["retweet_count"]).loc[df.nlargest(100, ["retweet_count"])["user"] == '0']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in nlargest(self, n, columns, keep)
#    5683         Brunei      434000    12128      BN
#    5684         """
# -> 5685         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5686
#    5687     def nsmallest(self, n, columns, keep="first") -> "DataFrame":
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/algorithms.py in nlargest(self)
#    1132
#    1133     def nlargest(self):
# -> 1134         return self.compute("nlargest")
#    1135
#    1136     def nsmallest(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/algorithms.py in compute(self, method)
# ...

# %%
df.loc[((df["user_statuses_count"] >= 2900) & (df["user_statuses_count"] <= 3500) &
    (df["user_friends_count"] >= 210) & (df["user_friends_count"] <= 230)
    & (df["user_followers_count"] >= 50000000))]
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 9741      9741  1588674838156         7092.0              1
# 12994    12994  1588532060312         1497.0              1
# 44671    44671  1588709847018         1472.0              1
# 54282    54282  1588689993810        97955.0              1
# 114336  114336  1588531965563         4304.0              1
# 193669  193669  1588663235674         2124.0              1
# 220804  220804  1588702736677         2024.0              1
# 250975  250975  1588532057357          499.0              1
# 360553  360553  1588531999704         1263.0              1
# 404803  404803  1588693907940         1586.0              1
# 441598  441598  1588713313370          782.0              1
# 543278  543278  1588650228633         4446.0              1
# 650945  650945  1588532004102         1322.0              1
# 724431  724430  1588587490880            NaN              1
# 741761  741760  1588611013021            NaN              1
# ...

# %%
df.loc[((df["user_statuses_count"] >= 2900) & (df["user_statuses_count"] <= 3500) &
    (df["user_friends_count"] >= 210) & (df["user_friends_count"] <= 230)
    & (df["user_followers_count"] >= 50000000))] = "Bill_Gates"

# %%
df.nlargest(100, ["retweet_count"]).loc[df.nlargest(100, ["retweet_count"])["user"] == '0']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-01eb731c0843> in <module>()
# ----> 1 df.nlargest(100, ["retweet_count"]).loc[df.nlargest(100, ["retweet_count"])["user"] == '0']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in nlargest(self, n, columns, keep)
#    5683         Brunei      434000    12128      BN
#    5684         """
# -> 5685         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5686
#    5687     def nsmallest(self, n, columns, keep="first") -> "DataFrame":
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/algorithms.py in nlargest(self)
#    1132
#    1133     def nlargest(self):
# -> 1134         return self.compute("nlargest")
#    1135
#    1136     def nsmallest(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/algorithms.py in compute(self, method)
# ...
